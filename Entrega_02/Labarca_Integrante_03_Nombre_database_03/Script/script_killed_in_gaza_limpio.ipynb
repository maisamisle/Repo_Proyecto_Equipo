# %%
from google.colab import files

# Esto abrirá un botón para seleccionar tu archivo CSV local
uploaded = files.upload()
# Out:
#      <input type="file" id="files-73fd9fd0-0eb5-40bf-90c9-05ea5fc3fd45" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-73fd9fd0-0eb5-40bf-90c9-05ea5fc3fd45">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Importar la librería Pandas
import pandas as pdf = pd.read_csv("Killed_In_Gaza_database_limpia.csv")

# Visualizar las primeras 5 filas de la base de datos
df.head()
# Out:
#   File "/tmp/ipykernel_5597/989197990.py", line 2
#     import pandas as pdf = pd.read_csv("Killed_In_Gaza_database_limpia.csv")
#                          ^
# SyntaxError: invalid syntax

# %%
# Importar la librería Pandas
import pandas as pd

# Cargar la base de datos limpia en un DataFrame
df = pd.read_csv('Killed_In_Gaza_database_limpia.csv')

# Visualizar las primeras filas de la base de datos
df.head()
# Out:
#   471058644;Yahya Mahmoud Abdel Rahman Al-Zarqa;???? ????? ??? ?????? ??????;0;09-01-2024;m;10;BEBE
# 0  470878935;Kanari Mutasim Mahmoud Aqel;????? ??...
# 1  470830738;Zina Ibrahim Hassan Abu Hamada;???? ...
# 2  470821901;Fatima Mohammed Saleh Antir;????? ??...
# 3  470819053;Anas Fawaz Haidar Owaida;??? ???? ??...
# 4  470783101;Saqr Badr Muhyi Al-Din Al-Hato;??? ?...
