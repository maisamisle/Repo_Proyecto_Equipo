# %%
import pandas as pd

df = pd.read_csv('/content/ataques_hospitales_database_limpia.csv', sep=';')
df.head()
# Out:
# /usr/local/lib/python3.13/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#    Attack ID                  Type of attack  \
# 0          1                       Airstrike
# 1          2                       Airstrike
# 2          3                       Airstrike
# 3          4  Inaccessible due to insecurity
# 4          5                       Airstrike
#
#                                             Category         Hospital name  \
# 0  Violence with heavy weapons, fire or chemical ...   Indonesian Hospital
# 1  Violence with heavy weapons, fire or chemical ...       Nasser Hospital
# 2  Violence with heavy weapons, fire or chemical ...      Al Quds Hospital
# 3                 Obstruction to healthcare delivery  Beit Hanoun Hospital
# ...
